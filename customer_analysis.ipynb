# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# warning library
#warnings.filterwarning("ignore")

# %%
cust = pd.read_csv("C:\\Users\\mohin\\Downloads\\customerbehaviouranalytics.csv")

# %%
cust
# Out:
#        Age     Income Marital_Status  Gender Education_Level  \
# 0       66   91643.09       Divorced  Female             PhD
# 1       47   30683.60        Married    Male     High School
# 2       52  125322.93         Single  Female             PhD
# 3       65   31508.33         Single    Male     High School
# 4       31   75736.11        Married  Female     High School
# ...    ...        ...            ...     ...             ...
# 49995   24   39049.29         Single    Male             PhD
# 49996   69  102566.21       Divorced  Female             PhD
# 49997   34  114722.99        Married    Male        Bachelor
# 49998   39   64790.09         Single  Female        Bachelor
# 49999   61  116965.23         Single    Male          Master
#
#        Purchases_in_Last_Month  Online_Activity_Level Product_Interest  \
# 0                            1                   0.26        Groceries
# 1                            5                   0.26      Electronics
# ...

# %%
cust.head()
# Out:
#    Age     Income Marital_Status  Gender Education_Level  \
# 0   66   91643.09       Divorced  Female             PhD
# 1   47   30683.60        Married    Male     High School
# 2   52  125322.93         Single  Female             PhD
# 3   65   31508.33         Single    Male     High School
# 4   31   75736.11        Married  Female     High School
#
#    Purchases_in_Last_Month  Online_Activity_Level Product_Interest  \
# 0                        1                   0.26        Groceries
# 1                        5                   0.26      Electronics
# 2                        2                   0.85        Groceries
# 3                        6                   0.31      Electronics
# 4                        2                   0.21      Electronics
#
#    Days_Since_Last_Purchase  Customer_Loyalty_Score Income_Category  \
# 0                       346                    0.18            High
# 1                        39                    6.40             Low
# ...

# %%
cust.tail()
# Out:
#        Age     Income Marital_Status  Gender Education_Level  \
# 49995   24   39049.29         Single    Male             PhD
# 49996   69  102566.21       Divorced  Female             PhD
# 49997   34  114722.99        Married    Male        Bachelor
# 49998   39   64790.09         Single  Female        Bachelor
# 49999   61  116965.23         Single    Male          Master
#
#        Purchases_in_Last_Month  Online_Activity_Level Product_Interest  \
# 49995                        4                   0.29            Other
# 49996                        8                   0.83        Groceries
# 49997                        2                   0.27      Electronics
# 49998                        2                   0.38        Groceries
# 49999                       17                   0.71          Fashion
#
#        Days_Since_Last_Purchase  Customer_Loyalty_Score Income_Category  \
# 49995                       333                    7.25             Low
# ...

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       50000 non-null  int64
#  1   Income                    50000 non-null  float64
#  2   Marital_Status            50000 non-null  object
#  3   Gender                    50000 non-null  object
#  4   Education_Level           50000 non-null  object
#  5   Purchases_in_Last_Month   50000 non-null  int64
#  6   Online_Activity_Level     50000 non-null  float64
#  7   Product_Interest          50000 non-null  object
#  8   Days_Since_Last_Purchase  50000 non-null  int64
#  9   Customer_Loyalty_Score    50000 non-null  float64
#  10  Income_Category           50000 non-null  object
#  11  Age_Income_Ratio          50000 non-null  float64
#  12  Is_Young_Professional     50000 non-null  int64
# ...

# %%
cust.describe(include='all')
# Out:
#                  Age         Income Marital_Status  Gender Education_Level  \
# count   50000.000000   50000.000000          50000   50000           50000
# unique           NaN            NaN              3       2               4
# top              NaN            NaN         Single  Female        Bachelor
# freq             NaN            NaN          16715   25086           12712
# mean       44.001300   85228.130454            NaN     NaN             NaN
# std        15.307342   37563.144114            NaN     NaN             NaN
# min        18.000000   20006.180000            NaN     NaN             NaN
# 25%        31.000000   52857.320000            NaN     NaN             NaN
# 50%        44.000000   84942.685000            NaN     NaN             NaN
# 75%        57.000000  118032.180000            NaN     NaN             NaN
# max        70.000000  149986.360000            NaN     NaN             NaN
#
# ...

# %%
cust.isnull().sum()
# Out:
# Age                         0
# Income                      0
# Marital_Status              0
# Gender                      0
# Education_Level             0
# Purchases_in_Last_Month     0
# Online_Activity_Level       0
# Product_Interest            0
# Days_Since_Last_Purchase    0
# Customer_Loyalty_Score      0
# Income_Category             0
# Age_Income_Ratio            0
# Is_Young_Professional       0
# Online_Purchase_Tendency    0
# Will_Purchase               0
# Annual_Spending             0
# dtype: int64

# %%
cust.duplicated().sum()
# Out:
# 0

# %%
cust.nunique()
# Out:
# Age                            53
# Income                      49889
# Marital_Status                  3
# Gender                          2
# Education_Level                 4
# Purchases_in_Last_Month        20
# Online_Activity_Level          91
# Product_Interest                4
# Days_Since_Last_Purchase      365
# Customer_Loyalty_Score       1001
# Income_Category                 2
# Age_Income_Ratio               35
# Is_Young_Professional           2
# Online_Purchase_Tendency      862
# Will_Purchase                   2
# Annual_Spending             48834
# dtype: int64

# %%
# EDA

plt.figure(figsize=(12,5))
ax=sns.histplot(cust['Age'],bins=20,color='red',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Insights**
#
# **Age Distribution**
# - Distribution is fairly spread.
# - In this distribution the middle age(30-60) has many customers than younger ones and elder ones.

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(cust['Income'],bins=20,color='red',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Income Distribution**
#
# - Distribution is roughly distributed
# - Income distribution is slightly peaking or concentrating around 80000
# - Individuals with less income and high income are also present but less compared to having high income

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(cust['Marital_Status'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Marital status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\2817511783.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(cust['Marital_Status'],palette='Set2')

# %% [markdown]
# **Marital status**
# - there are more individuals who are are married followed by single and divorced

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x=cust['Gender'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\3731624367.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cust['Gender'],palette='coolwarm')

# %% [markdown]
# **Gender Distribution**
# - Female customers are more than Male Customers

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x=cust['Education_Level'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Education level Distribution')
plt.xlabel('Eduaction')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\1988895929.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cust['Education_Level'],palette='coolwarm')

# %% [markdown]
# **Eduaction Level distribution**
# - Bachelor individuals are more followed by highschool, phd and master

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x=cust['Purchases_in_Last_Month'])#,palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Purchases_in_Last_Month Distribution')
plt.xlabel('Purchases_in_Last_Month')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Purchases in last month distribution**
#
# - Distribution is normally equally distributed.
# - There are two days with significantly higher purchase counts(7 and 15).

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(x=cust['Online_Activity_Level'],kde=True,bins=20)#,palette='coolwarm')
#for bars in ax.containers:
    #ax.bar_label(bars)
plt.title('Online_Activity_Level Distribution')
plt.xlabel('Online_Activity_Level')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Online Activity level distribution**
# - Ditribution is fairly spread.
# - The peak of the distribution seems to be around the 0.4-0.5 range.

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x=cust['Product_Interest'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Product interest Distribution')
plt.xlabel('product interest')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\1385130002.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cust['Product_Interest'],palette='Set2')

# %% [markdown]
# **Product Interest Distribution**
# - The product interests are not evenly distributed.
# - Electronics have highest interest followed by groceries, fashions and other.
# - Groceries also have highest customer interest.
# - The fashion and other categories have same customer interest.

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(cust['Days_Since_Last_Purchase'],bins=20,color='orange',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Days_Since_Last_Purchase Distribution')
plt.xlabel('Days_Since_Last_Purchase')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Day since last purchase distribution**
# - Distribution is roughly distributed.
# - Day since last purchase distribution is slightly peaking or concentrating around 200-250.

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(cust['Customer_Loyalty_Score'],bins=20,color='purple',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Customer_Loyalty_Score Distribution')
plt.xlabel('Customer_Loyalty_Score')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Customer Loyalty score distribution**
# - This distribution is roughly distributed.
# - Customer loyalty distribution is distributed lesser between range 4-5 compare than other.

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(cust['Income_Category'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Income category Distribution')
plt.xlabel('Income category')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\3222885483.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(cust['Income_Category'],palette='Set2')

# %% [markdown]
# **Income category distribution**
# - Distribution is fairly distributed.
# - The High income category has a count of 26981 which is susbstantially higher than the low income category with a count of 23019

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(cust['Age_Income_Ratio'],bins=20,color='red',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Age_Income_Ratio Distribution')
plt.xlabel('Age_Income_Ratio')
plt.ylabel('Distribution')
plt.show()

# %% [markdown]
# **Age income ratio distribution**
# - The distribution shows a right-skewed distribution.
# - The distribution peaks around an age-income-ratio of 0.0005 indicationg that this is the most common ratio among customers.

# %%
plt.figure(figsize=(12,5))
ax=sns.boxplot(x='Age_Income_Ratio',data=cust)#,bins=20,color='red',kde=True)
#for bars in ax.containers:
    #ax.bar_label(bars)
plt.title('Age_Income_Ratio Distribution')
plt.xlabel('Age_Income_Ratio')
plt.ylabel('Distribution')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Age income ratio column contains outliers

# %%
# selected column with outliers
column_with_outliers = cust['Age_Income_Ratio']

# applying transformation
column_with_outliers_log = np.log1p(column_with_outliers)
# create a new column with the log-transformed values
cust['Age_Income_Ratio_Log'] = column_with_outliers_log

# square root transformation

column_with_outliers_sqrt = np.sqrt(column_with_outliers.abs())

cust['Age_Income_Ratio_sqrt'] = column_with_outliers_sqrt

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.boxplot(column_with_outliers)
plt.title("Original data")

plt.subplot(1,3,2)
plt.boxplot(column_with_outliers_log)
plt.title("log transformed data")

plt.subplot(1,3,3)
plt.boxplot(column_with_outliers_sqrt)
plt.title("sqaure root transformed data")

plt.show()

# %% [raw]
# plt.figure(figsize=(8,4))
# ax=sns.countplot(cust['Is_Young_Professional'],palette='Set2')
# for bars in ax.containers:
#     ax.bar_label(bars)
# plt.title('Is_Young_Professional Distribution')
# plt.xlabel('Is_Young_Professional')
# plt.ylabel('Distribution')
# plt.show()

# %%
sns.boxplot(cust['Age_Income_Ratio'])
# Out:
# <Axes: ylabel='Age_Income_Ratio'>

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(cust['Online_Purchase_Tendency'],bins=20,color='red',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Online_Purchase tendency Distribution')
plt.xlabel('online purchase tendency')
plt.ylabel('Distribution')
plt.show()

# %%
num=['Age','Income','Purchases_in_Last_Month','Online_Activity_Level','Days_Since_Last_Purchase','Annual_Spending',"Online_Purchase_Tendency","Age_Income_Ratio"]
def univariate_analysis(n):
    plt.figure(figsize=(20, 24))
    for i, col in enumerate(n, 1):
        plt.subplot(4,2,i)
        plt.title(f"Count of {col}")
        sns.boxplot(x=cust[col])
    plt.show()

univariate_analysis(num)

# %%
num=['Age','Income','Purchases_in_Last_Month','Online_Activity_Level','Days_Since_Last_Purchase','Annual_Spending',"Online_Purchase_Tendency","Age_Income_Ratio"]
def univariate_analysis(n):
    plt.figure(figsize=(20, 24))
    for i, col in enumerate(n, 1):
        plt.subplot(4,2,i)
        plt.title(f"Count of {col}")
        sns.histplot(x=cust[col],kde=True,bins=20)
    plt.show()

univariate_analysis(num)

# %%
# will purchase vs age
plt.figure(figsize=(8,4))
sns.boxplot(data=cust,x='Will_Purchase',y='Age',palette='coolwarm')
plt.title('Age vs Will purchase')
plt.xlabel('Will purchase')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\1748710583.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=cust,x='Will_Purchase',y='Age',palette='coolwarm')

# %% [markdown]
# **Age vs Will Purchase**
# - It appears that those who will purchase(1) tend to have a higher median age compared to those who will not purchase(0).
# - There are some outliers in the data specially for the "will Purchase" category(1). These are individuals whose ages are significantly different from the majority in that category.

# %%
# will purchase vs Income
plt.figure(figsize=(8,4))
sns.boxplot(data=cust,x='Will_Purchase',y='Income',palette='coolwarm')
plt.title('Income vs Will purchase')
plt.xlabel('Will purchase')
plt.ylabel('Income')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\1584493911.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=cust,x='Will_Purchase',y='Income',palette='coolwarm')

# %% [markdown]
# **Income vs will purchase**
# - Income could be a strong indicator of purchasing behaviour. Customer with higher incomes are more inclined to purchases.
# - The median income for customers who will purchase(1) is higher than those who will purchase(0).

# %%
# Age vs Annual Spending
plt.figure(figsize=(8,4))
sns.scatterplot(data=cust,x='Age',y='Annual_Spending',color='red')
plt.title('Age vs Annual Spending')
plt.xlabel('Age')
plt.ylabel('Annual Spending')
plt.show()

# %% [markdown]
# **Age vs Annual spending**
# - There does not seem to be a strong correlation between age and annual spending.

# %%
# customer loyaly score vs Annual Spending
plt.figure(figsize=(8,4))
sns.scatterplot(data=cust,x='Customer_Loyalty_Score',y='Annual_Spending',color='purple')
plt.title('Customer loyalty score vs Annual Spending')
plt.xlabel('customer score')
plt.ylabel('Annual Spending')
plt.show()

# %% [markdown]
# **Customer loyalty score vs Annual spending**
# - Who have higher loyalty score those income is annual spending is high.

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(data=cust, x='Gender',hue='Will_Purchase',palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Gender vs will purchase')
plt.xlabel('Gender')
plt.ylabel('will purchase')
plt.show()

# %% [markdown]
# **Gender vs will purchase**
# - Female will purchase(1) this group has the highest count(18995) among all categories, suggesting that a significantly large number of female intend to make a purchase.

# %%
Features = ['Age','Income','Purchases_in_Last_Month','Online_Activity_Level','Days_Since_Last_Purchase','Customer_Loyalty_Score',
            'Age_Income_Ratio','Is_Young_Professional','Online_Purchase_Tendency','Will_Purchase','Annual_Spending']
plt.figure(figsize=(10,5))
corr_matrix=cust[Features].corr()
sns.heatmap(corr_matrix,annot=True,vmin=-1,vmax=1)
plt.title("Correlation matrix numerical features")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=cust, x='Annual_Spending',y='Product_Interest',palette='coolwarm')

plt.title('Annual spending  vs product interest')
plt.xlabel('annual spending')
plt.ylabel('product interest')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\1530889337.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=cust, x='Annual_Spending',y='Product_Interest',palette='coolwarm')

# %% [markdown]
# **Insights**

# %% [markdown]
# **Univariate analysis for categorical columns**

# %%
num_col = ['Age','Income','Purchases_in_Last_Month','Onilne_Activity_Level','Days_since_Last_Purchase','Customer_Loyalty_Score',
           'Age_Income_Ratio','Is_Young_Professional','Online_Purchase_Tendency','Will_Purchase','Annual_Spending']
cat_col = ['Gender','Marital_Status','Education_Level','Product_Interest','Income_Category']
def univariate_analysis_categorical(cat_col):
    for i in cat_col:
        plt.figure(figsize=(8,4))
        cust[i].value_counts().head(20).plot(kind='bar')
univariate_analysis_categorical(cat_col)

# %% [markdown]
# **Insights**

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x=cust['Will_Purchase'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Will_Purchase Distribution')
plt.xlabel('Will_Purchase')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_848\2979727082.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cust['Will_Purchase'],palette='coolwarm')

# %% [markdown]
# **Will purchase distribution**
# - The will purchase column contain high class imbalance

# %% [markdown]
# **Bivariate Analysis**

# %%
num = ['Gender','Education_Level','Product_Interest','Income_Category']
def bivariate_analysis(n):
    plt.figure(figsize=(15,10))
    for i,col in enumerate(n,1):
        plt.subplot(2,2,i)
        plt.title(f"count of {col}")
        sns.countplot(x=cust[col],hue='Will_Purchase',data=cust)
    plt.show()

bivariate_analysis(num)

# %% [markdown]
# **Class Imbalance**
# - Class imbalance happens when the number of instances in one class are higher than another data.

# %% [markdown]
# **Kurtosis**
# - kurtosis is a statistical measure that describe tha shape of a distribution to its peak.
# - It provide insights into the "tailedness" or extremely of data points.

# %% [markdown]
# **Types of Kurtosis**
# - Mesokurtic (kurtosis = 3) : The distribution has a normal shape.
# - leptokurtic (kurtosis > 3) : The distribution has heavy tails and a sharp peak and it indicate more extreme outlier than a normal distribution.
# - platykurtic (kurtosis < 3) : The distribution has light tails and a flatter peak and fewer extreme outliers compared to normal distribution.

# %% [markdown]
# **Skewness**
# - Skewness measures the asymmetry of a distribution.
# - It can indicate whether the data is symmetric or skewed to the left or right.

# %% [markdown]
# **Types of skewness**
# - Skewness = 0 : Perfectly symmetric distribution (eg. normal distribution).
# - Positive skewness (>0) : The tail on the right side is longer, and the bulk of data is concentrated on the left.
# - Negative skewness (<0) : The tail on the left side is longer, and the bulk of data is concentrated on the right.

# %%
from scipy.stats import skew, kurtosis
# we can apply skew and kurtosis only on numerical columns
num_col = cust.select_dtypes(include=['int64','float64']).columns
skewness = cust[num_col].apply(skew).rename("Skewness")
kurtosisvalue = cust[num_col].apply(kurtosis).rename("Kurtosis")
# concating has applied for defining list properly
distributionmetrics = pd.concat([skewness,kurtosisvalue],axis=1)

# %%
distributionmetrics
# Out:
#                           Skewness  Kurtosis
# Age                       0.006173 -1.201301
# Income                    0.000163 -1.201428
# Purchases_in_Last_Month   0.000253 -1.208863
# Online_Activity_Level     0.001181 -1.191590
# Days_Since_Last_Purchase -0.001653 -1.195425
# Customer_Loyalty_Score    0.005806 -1.199872
# Age_Income_Ratio          1.901656  4.181303
# Is_Young_Professional     1.316007 -0.268125
# Online_Purchase_Tendency  0.893251  0.024135
# Will_Purchase             1.193493 -0.575574
# Annual_Spending          -0.015575 -0.142728
# Age_Income_Ratio_Log      1.899717  4.170871
# Age_Income_Ratio_sqrt     1.037563  0.962652

# %% [markdown]
# **Log Transformation**
# - When data distribution is right skewed (positive values).
# - It reduce the impact of large values.
# - Log transformation useful for regression model where extreme values dominated prediction.

# %%
cust['Age_Income_Ratio'] = np.log1p(cust['Age_Income_Ratio'])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Age_Income_Ratio',data=cust)
plt.show()

# %%
from scipy.stats import skew, kurtosis
num_col = cust.select_dtypes(include=['int64','float64']).columns
skewness = cust[num_col].apply(skew).rename("Skewness")
kurtosisvalue = cust[num_col].apply(kurtosis).rename("Kurtosis")
distributionmetrics = pd.concat([skewness,kurtosisvalue],axis=1)

# %%
distributionmetrics
# Out:
#                           Skewness  Kurtosis
# Age                       0.006173 -1.201301
# Income                    0.000163 -1.201428
# Purchases_in_Last_Month   0.000253 -1.208863
# Online_Activity_Level     0.001181 -1.191590
# Days_Since_Last_Purchase -0.001653 -1.195425
# Customer_Loyalty_Score    0.005806 -1.199872
# Age_Income_Ratio          1.899717  4.170871
# Is_Young_Professional     1.316007 -0.268125
# Online_Purchase_Tendency  0.893251  0.024135
# Will_Purchase             1.193493 -0.575574
# Annual_Spending          -0.015575 -0.142728
# Age_Income_Ratio_Log      1.899717  4.170871
# Age_Income_Ratio_sqrt     1.037563  0.962652

# %% [markdown]
# **Square root transformation**
# - When data distribution is right skewed (less extreme value).
# - Impact of large value but not as much as log transformation.

# %%
cust['Online_Purchase_Tendency'] = np.sqrt(cust['Online_Purchase_Tendency'])

# %%
from scipy.stats import skew, kurtosis
num_col = cust.select_dtypes(include=['int64','float64']).columns
skewness = cust[num_col].apply(skew).rename("Skewness")
kurtosisvalue = cust[num_col].apply(kurtosis).rename("Kurtosis")
distributionmetrics = pd.concat([skewness,kurtosisvalue],axis=1)

# %%
distributionmetrics
# Out:
#                           Skewness  Kurtosis
# Age                       0.006173 -1.201301
# Income                    0.000163 -1.201428
# Purchases_in_Last_Month   0.000253 -1.208863
# Online_Activity_Level     0.001181 -1.191590
# Days_Since_Last_Purchase -0.001653 -1.195425
# Customer_Loyalty_Score    0.005806 -1.199872
# Age_Income_Ratio          1.899717  4.170871
# Is_Young_Professional     1.316007 -0.268125
# Online_Purchase_Tendency -0.014797 -0.615005
# Will_Purchase             1.193493 -0.575574
# Annual_Spending          -0.015575 -0.142728
# Age_Income_Ratio_Log      1.899717  4.170871
# Age_Income_Ratio_sqrt     1.037563  0.962652

# %% [markdown]
# **Heatmap**

# %% [raw]
# Features = ['Age','Income','Purchases_in_Last_Month','Onilne_Activity_Level','Days_since_Last_Purchase','Customer_Loyalty_Score',
#             'Age_Income_Ratio','Is_Young_Professional','Online_Purchase_Tendency','Will_Purchase','Annual_Spending']
# plt.figure(figsize=(10,5))
# corr_matrix=cust[Features].corr()
# sns.heatmap(corr_matrix,annot=True,vmin=-1,vmax=1)
# plt.title("Correlation matrix numerical features")
# plt.show()

# %% [markdown]
# # ANNOVA

# %% [markdown]
# **Definition** :
# - ANNOVA stands for Analysis of Variance.
# - ANNOVA is a statistical test used to compare the means of two or more groups and determine if they are significantly different from each other.
# - It can apply only categorical data.
# - It can calculated by two methods:
# - 1.F-statistics : The ratio of variance between group to variance within groups.
# - 2.p-value : It is the probability of observing data to true differences between the group. If p-value < 0.05 i.e. we reject the null hypothesis, if p-value > 0.05 then

# %% [markdown]
# **Types of ANNOVA**
#
# 1.ONE-WAY :
# - There is only one independent variable and with more thean two levels or groups.
#
# 2.TWO-WAY :
# - Two-way ANNOVA is two different categorical independent variables on one dependent variables.

# %%
from scipy.stats import f_oneway 

cust_cat_features = ['Product_Interest']
for feature in cust_cat_features:
    groups = [cust[cust[feature] == category]['Annual_Spending'] for category in cust[feature].unique()]
    f_stat, p_value = f_oneway(*groups) #unpacks the list of groups into separate arguments for the function.
    
    print(f"ANOVA results for {feature}:")
    print(f" F-statistic: {f_stat:.2f}")
    print(f" P-value: {p_value:.4f}\n")
# Out:
# ANOVA results for Product_Interest:
#  F-statistic: 1.12
#  P-value: 0.3376

# %% [markdown]
# **Product_Interest**
# - f-statistic = 1.12
# - p-value = 0.3376. The p-value is greater than 0.05 means the product interest has no significant effect and we fail to reject the null hypothesis.

# %% [markdown]
# **Formulated Hypothesis**:
# - Hypothesis 1 : Higher loyalty score and online activity levels are associated with higher spending.
# - Hypothesis 2 : Customer with shorter recency periods are more likely to purchase.
# - Hypothesis 3 : Income category has a significant influence on purchase likelihood.
# - Hypothesis 4 : Product interest is a key factor influencing annual spending.

# %%
# Hypothesis 1 : online activity level vs customer loyalty score
from scipy.stats import f_oneway # performs a one-way ANNOVA test for only one independent variable.
# define categorical columns
cust_cat_features = ['Customer_Loyalty_Score','Online_Activity_Level']
for feature in cust_cat_features:
    groups = [cust[cust[feature] == category]['Annual_Spending'] for category in cust[feature].unique()]
    f_stat, p_value = f_oneway(*groups) #unpacks the list of groups into separate arguments for the function.
    
    print(f"ANOVA results for {feature}:")
    print(f" F-statistic: {f_stat:.2f}")
    print(f" P-value: {p_value:.4f}\n")
# Out:
# ANOVA results for Customer_Loyalty_Score:
#  F-statistic: 16.86
#  P-value: 0.0000
#
# ANOVA results for Online_Activity_Level:
#  F-statistic: 1.22
#  P-value: 0.0741

# %% [markdown]
# **Customer Loyalty Score**
# - p-value is 0.0000 means value is less than 0.05 then reject null hypothesis.

# %% [markdown]
# **Online activity level**
# - p-value is 0.0741 means value is greater than 0.05 then fail to reject null hypothesis.

# %%
# Hypothesis 2 : Days since last purchase and will purchase
from scipy.stats import f_oneway # performs a one-way ANNOVA test for only one independent variable.

cust_cat_features = ['Days_Since_Last_Purchase']
for feature in cust_cat_features:
    groups = [cust[cust[feature] == category]['Will_Purchase'] for category in cust[feature].unique()]
    f_stat, p_value = f_oneway(*groups) #unpacks the list of groups into separate arguments for the function.
    
    print(f"ANOVA results for {feature}:")
    print(f" F-statistic: {f_stat:.2f}")
    print(f" P-value: {p_value:.4f}\n")
# Out:
# ANOVA results for Days_Since_Last_Purchase:
#  F-statistic: 4.21
#  P-value: 0.0000

# %% [markdown]
# **Days since last purchase**
# - p-value is 0.0000 means value is less than 0.05 then reject null hypothesis.

# %% [markdown]
# # T-test

# %% [markdown]
# - A t-test is a statistical test used to compare the means of two groups.
# - t-statistic is measure how strong the relationship is between the independent and dependent variable.

# %%
# t-test for means of two independent samples of scores
from scipy.stats import ttest_ind # ttest_ind is for independent samples

group_1 = cust[cust['Will_Purchase']==1]['Days_Since_Last_Purchase']
group_0 = cust[cust['Will_Purchase']==0]['Days_Since_Last_Purchase']
t_statistic, p_value = ttest_ind(group_1,group_0)
print(f"T-statistic : {t_statistic:.4f}")
# Out:
# T-statistic : -16.1719

# %%
# Hypothesis 3 : Income category and will purchase
from scipy.stats import f_oneway # performs a one-way ANNOVA test for only one independent variable.

cust_cat_features = ['Income_Category']
for feature in cust_cat_features:
    groups = [cust[cust[feature] == category]['Will_Purchase'] for category in cust[feature].unique()]
    f_stat, p_value = f_oneway(*groups) #unpacks the list of groups into separate arguments for the function.
    
    print(f"ANOVA results for {feature}:")
    print(f" F-statistic: {f_stat:.2f}")
    print(f" P-value: {p_value:.4f}\n")
# Out:
# ANOVA results for Income_Category:
#  F-statistic: 1456.99
#  P-value: 0.0000

# %% [markdown]
# **Income Category**
# - p-value is 0.0000 means value is less than 0.05 then reject null hypothesis.

# %% [markdown]
# # OLS
#
# - OLS stands for ordinary least squares rehression.
# - Provide insights into the relationship between dependent variable and one or more independent variable.

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# OLS (Ordinary Least Squares regression)
import statsmodels.api as sm
n = cust[['Online_Activity_Level','Customer_Loyalty_Score']]
m = cust['Annual_Spending']
n = sm.add_constant(n) # Here n means online activity level and customer loyalty score is constant
model = sm.OLS(m,n).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Annual_Spending   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     7985.
# Date:                Sun, 16 Feb 2025   Prob (F-statistic):               0.00
# Time:                        15:31:08   Log-Likelihood:            -4.6409e+05
# No. Observations:               50000   AIC:                         9.282e+05
# Df Residuals:                   49997   BIC:                         9.282e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4529.2248     33.781    134.077      0.000    4463.014    4595.436
# ...

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       50000 non-null  int64
#  1   Income                    50000 non-null  float64
#  2   Marital_Status            50000 non-null  object
#  3   Gender                    50000 non-null  object
#  4   Education_Level           50000 non-null  object
#  5   Purchases_in_Last_Month   50000 non-null  int64
#  6   Online_Activity_Level     50000 non-null  float64
#  7   Product_Interest          50000 non-null  object
#  8   Days_Since_Last_Purchase  50000 non-null  int64
#  9   Customer_Loyalty_Score    50000 non-null  float64
#  10  Income_Category           50000 non-null  object
#  11  Age_Income_Ratio          50000 non-null  float64
#  12  Is_Young_Professional     50000 non-null  int64
# ...

# %% [markdown]
# # Chi Square Test
#
# - checking if two categorical variables are related or not.
# - comparing observed vs expected frequencies.
# - If there is a big difference what is expected and what observed that suggest the two variable might be.

# %%
import pandas as pd
from scipy.stats import chi2_contingency # contingency use for calculate the statistical significance of the relationship

# perform chi square test on two or more categorical variables
contingency_table = pd.crosstab(cust['Income_Category'],cust['Will_Purchase']) # crosstab fro comparing two variable
chi2_test,p,Dof,expected = chi2_contingency(contingency_table)
print("p-value:",p) # check value is greater than 0.05 or not
if p<0.05:
    print("The variable are realted")
else:
    print("The variable are not related")

print("chi square test:",chi2_test)
print("Degree of freedom:",Dof) # Dof is number of independent values
print("Expected frequancy:\n",expected)
# Out:
# p-value: 1.151162598771326e-309
# The variable are realted
# chi square test: 1415.0081584840607
# Degree of freedom: 1
# Expected frequancy:
#  [[20403.57182  6577.42818]
#  [17407.42818  5611.57182]]

# %% [markdown]
# chi sqr insight

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
cat_col = ['Marital_Status','Gender','Education_Level','Product_Interest','Income_Category']
for column in cat_col:
    cust[column] = label_encoder.fit_transform(cust[column])

# %%
from sklearn.model_selection import train_test_split
x = cust.drop(columns=['Will_Purchase'])
y = cust['Will_Purchase']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# classification model
from sklearn.model_selection import train_test_split
x = cust[['Is_Young_Professional','Age','Online_Purchase_Tendency','Income','Purchases_in_Last_Month','Online_Activity_Level','Customer_Loyalty_Score','Days_Since_Last_Purchase']]
y = cust['Will_Purchase']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score
x = cust.drop(columns=['Will_Purchase'])
y = cust['Will_Purchase']

rf=RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)

y_pred=rf.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)

class_report = classification_report(y_test,y_pred)
print("Classification Report:",class_report)
# Out:
# Accuracy: 0.9999
# Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7607
#            1       1.00      1.00      1.00      2393
#
#     accuracy                           1.00     10000
#    macro avg       1.00      1.00      1.00     10000
# weighted avg       1.00      1.00      1.00     10000

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report

gbc_classifier=GradientBoostingClassifier(n_estimators=100,random_state=42)

gbc_classifier.fit(x_train,y_train)

y_pred=gbc_classifier.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

class_report=classification_report(y_test,y_pred)
print("Gradient boosting classifier's classification report\n:",class_report)
# Out:
# Accuracy 1.0
# Gradient boosting classifier's classification report
# :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7607
#            1       1.00      1.00      1.00      2393
#
#     accuracy                           1.00     10000
#    macro avg       1.00      1.00      1.00     10000
# weighted avg       1.00      1.00      1.00     10000

# %%
from  sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
#initialize 
knn_classifier=KNeighborsClassifier()

knn_classifier.fit(x_train,y_train)

y_pred=knn_classifier.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

classification_rep=classification_report(y_test,y_pred)
print("knn classifier's classification report\n:",classification_rep)
# Out:
# Accuracy 0.7492
# knn classifier's classification report
# :               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85      7607
#            1       0.46      0.27      0.34      2393
#
#     accuracy                           0.75     10000
#    macro avg       0.63      0.59      0.59     10000
# weighted avg       0.72      0.75      0.72     10000

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score
svc_model=SVC()
svc_model.fit(x_train,y_train)
y_pred=svc_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
class_report=classification_report(y_test,y_pred)
print("classification report:\n",class_report)
# Out:
# Accuracy: 0.7607
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      7607
#            1       0.00      0.00      0.00      2393
#
#     accuracy                           0.76     10000
#    macro avg       0.38      0.50      0.43     10000
# weighted avg       0.58      0.76      0.66     10000
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from xgboost import XGBClassifier 

xgb_classifier=XGBClassifier(n_estimators=100,random_state=42)

xgb_classifier.fit(x_train,y_train)

y_pred=xgb_classifier.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

class_report=classification_report(y_test,y_pred)
print("XGB classifier's classification report\n:",class_report)
# Out:
# Accuracy 0.9993
# XGB classifier's classification report
# :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7607
#            1       1.00      1.00      1.00      2393
#
#     accuracy                           1.00     10000
#    macro avg       1.00      1.00      1.00     10000
# weighted avg       1.00      1.00      1.00     10000

# %%
from  sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
 
knn_classifier=KNeighborsClassifier()

knn_classifier.fit(x_train,y_train)

y_pred=knn_classifier.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

class_report=classification_report(y_test,y_pred)
print("knn classifier's classification report\n:",class_report)
# Out:
# Accuracy 0.7492
# knn classifier's classification report
# :               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85      7607
#            1       0.46      0.27      0.34      2393
#
#     accuracy                           0.75     10000
#    macro avg       0.63      0.59      0.59     10000
# weighted avg       0.72      0.75      0.72     10000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score


model=LinearRegression()
model.fit(x_train, y_train)
y_pred_test=model.predict(x_test)
y_pred_train=model.predict(x_train)
lr_metrics={'Test Mean Squared Error ':mean_squared_error(y_test,y_pred_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_pred_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_pred_test),
           'Test R Squared':r2_score(y_test,y_pred_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_pred_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_pred_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_pred_train),
           'Train R Squared':r2_score(y_train,y_pred_train)}
print(lr_metrics)
# Out:
# {'Test Mean Squared Error ': 0.0975384138653003, 'Test Root Mean Squared Error': 0.3123114052757284, 'Test Mean Absolute Error': 0.23321736710151791, 'Test R Squared': 0.46417919303052313, 'Train Mean Squared Error': 0.09870181270790272, 'Train Root Mean Squared Error': 0.3141684463912675, 'Train Mean Absolute Error': 0.23607462096386903, 'Train R Squared': 0.46625739198087435}

# %%
#multiple linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score


mlr=LinearRegression()
mlr.fit(x_train, y_train)
y_predmlr_test=mlr.predict(x_test)
y_predmlr_train=mlr.predict(x_train)
mlr_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predmlr_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predmlr_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predmlr_test),
           'Test R Squared':r2_score(y_test,y_predmlr_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predmlr_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predmlr_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predmlr_train),
           'Train R Squared':r2_score(y_train,y_predmlr_train)}

print(mlr_metrics)
# Out:
# {'Test Mean Squared Error': 0.0975384138653003, 'Test Root Mean Squared Error': 0.3123114052757284, 'Test Mean Absolute Error': 0.23321736710151791, 'Test R Squared': 0.46417919303052313, 'Train Mean Squared Error': 0.09870181270790272, 'Train Root Mean Squared Error': 0.3141684463912675, 'Train Mean Absolute Error': 0.23607462096386903, 'Train R Squared': 0.46625739198087435}

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_preddt=model.predict(x_test)

dt_metrics={'Mean Squared Error':mean_squared_error(y_test,y_preddt),
           'Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_preddt)),
           'Mean Absolute Error':mean_absolute_error(y_test,y_preddt),
           'R Squared':r2_score(y_test,y_preddt)}

print(dt_metrics)
# Out:
# {'Mean Squared Error': 0.0001, 'Root Mean Squared Error': 0.01, 'Mean Absolute Error': 0.0001, 'R Squared': 0.9994506566328735}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_predrf_test=rf.predict(x_test)
y_predrf_train=rf.predict(x_train)
rf_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predrf_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predrf_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predrf_test),
           'Test R Squared':r2_score(y_test,y_predrf_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predrf_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predrf_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predrf_train),
           'Train R Squared':r2_score(y_train,y_predrf_train)}

print(rf_metrics)
# Out:
# {'Test Mean Squared Error': 4.901000000000001e-05, 'Test Root Mean Squared Error': 0.007000714249274856, 'Test Mean Absolute Error': 0.00010700000000000001, 'Test R Squared': 0.9997307668157712, 'Train Mean Squared Error': 6.8300000000000015e-06, 'Train Root Mean Squared Error': 0.002613426869074396, 'Train Mean Absolute Error': 3.850000000000001e-05, 'Train R Squared': 0.9999630659061596}

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
y_predgb_test=gb.predict(x_test)
y_predgb_train=gb.predict(x_train)
gb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predgb_test),
           'Test R Squared':r2_score(y_test,y_predgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predgb_train),
           'Train R Squared':r2_score(y_train,y_predgb_train)}
gb_metrics
# Out:
# {'Test Mean Squared Error': 0.001539541690615005,
#  'Test Root Mean Squared Error': 0.03923699390390407,
#  'Test Mean Absolute Error': 0.011533636036656417,
#  'Test R Squared': 0.9915426298384584,
#  'Train Mean Squared Error': 0.001564563280305764,
#  'Train Root Mean Squared Error': 0.039554560802842496,
#  'Train Mean Absolute Error': 0.011849111900888823,
#  'Train R Squared': 0.9915394250345465}

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
y_predxgb_test=xgb.predict(x_test)
y_predxgb_train=xgb.predict(x_train)
xgb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predxgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predxgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predxgb_test),
           'Test R Squared':r2_score(y_test,y_predxgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predxgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predxgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predxgb_train),
           'Train R Squared':r2_score(y_train,y_predgb_train)}

print(xgb_metrics)
# Out:
# {'Test Mean Squared Error': 0.0003456937391349876, 'Test Root Mean Squared Error': 0.018592841072170428, 'Test Mean Absolute Error': 0.0008047121271953163, 'Test R Squared': 0.9981009543734901, 'Train Mean Squared Error': 1.6319207324030708e-06, 'Train Root Mean Squared Error': 0.0012774665288777906, 'Train Mean Absolute Error': 0.0001722620980430185, 'Train R Squared': 0.9915394250345465}

# %%
import shap
# create shap explainer for trained the model
explainer=shap.Explainer(model,x_train)
shap_values=explainer(x_test)  # shap_values for test data
#summary plot
shap.summary_plot(shap_values,x_test)  # visulize shap values

# %%
# GridSearch
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

xgb_model = XGBRegressor(random_state=42)

param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'min_child_weight': [1, 3, 5]
}

# performing GridSearchCV
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3,  
    scoring='neg_mean_squared_error', 
    verbose=2,
    n_jobs=-1
)

# fitting GridSearchCV
grid_search.fit(x_train, y_train)

# displaying the best parameters
print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# Best parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 100, 'subsample': 0.8}

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Defining the parameter grid
param_dist = {
    'n_estimators': np.arange(100, 301, 50),
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initializing RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=GradientBoostingRegressor(random_state=42),
    param_distributions=param_dist,
    scoring='neg_mean_absolute_error',
    n_iter=20,  # no. of random combinations to test
    cv=3,
    verbose=2,
    n_jobs=-1,
    random_state=42
)

# Fit the model
random_search.fit(x_train, y_train)

# Best parameters and best score
best_params = random_search.best_params_
best_score = -random_search.best_score_ 
print("Best Parameters:", best_params)
print("Best MAE:", best_score)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 5, 'learning_rate': 0.1}
# Best MAE: 0.00017500765765808516

# %%
import pickle
with open("customer_analysis.pkl", "wb") as f:
    pickle.dump(model, f)
